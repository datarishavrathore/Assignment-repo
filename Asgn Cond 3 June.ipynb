# %%
#Take calculate profit percentage
cp=int(input("enter the cost price="))
sp=int(input("enter the selling price="))
if sp>cp:
    profit=cp-sp
    profit_percent = (profit / cp) * 100
    print("Profit Percentage =", profit_percent, "%")
elif cp > sp:
    loss = cp - sp
    loss_percent = (loss / cp) * 100
    print("Loss Percentage =", loss_percent, "%")
else:
    print("No Profit No Loss")
# Out:
# enter the cost price= 455
# enter the selling price= 23
# Profit Percentage = 94.94505494505493 %

# %%
total_runs = 0

for i in range(1, 6):
    runs = int(input(f"Enter runs scored by Player {i}: "))
    total_runs += runs

average_runs = total_runs / 5

print("\nCricket Stats")
print("Total Runs:", total_runs)
print("Average Runs:", average_runs)
# Out:
# Enter runs scored by Player 1:  45
# Enter runs scored by Player 2:  45
# Enter runs scored by Player 3:  34
# Enter runs scored by Player 4:  23
# Enter runs scored by Player 5:  2
# Cricket Stats
# Total Runs: 149
# Average Runs: 29.8

# %%
#3Objective: Write a program that prompts the user for their age and tells them how 
#many years until they reach retirement age (65). 
#● Hints: 
#○ Ask the user to input their age. 
#○ Calculate how many more years they have until they reach 65 years of 
#age. 
#○ Display the number of years left until retirement or a message if the user 
#has already reached retirement age
age = int(input("Enter your age: "))
retirement_age = 65

years_left = retirement_age - age

if years_left > 0:
    print("Years left until retirement:", years_left)
else:
    print("You have already reached retirement age")
# Out:
# Enter your age:  34
# -31

# %%
#4. Task: Calculate the Area of a Circle 
#● Objective: Write a program to calculate the area of a circle. 
#● Hints: 
#○ Ask the user to input the radius of the circle. 
#○ Calculate the area of the circle using the formula: Area = π * 
#radius^2. 
#○ Display the calculated area. 

import math

radius = float(input("Enter the radius of the circle: "))

area = math.pi * (radius ** 2)

print("Area of circle is:", area)
# Out:
# Enter the radius of the circle:  67
# Area of circle is: 14102.609421964582

# %%
# 5 Task: Salary Calculation 
# Objective: You have to calculate an employee's salary by computing the gross 
#salary tax and net salary based on the given parameters. 
# Hints: 
# Base Salary = ₹50000 
# Bonus = ₹5000 
# Tax Rate = 10%  
# Other Charges = ₹2000 
#Display the Gross Salary Tax and Net Salary. 

# Given values
base_salary = 50000
bonus = 5000
other_charges = 2000
tax_rate = 10

# Step 1: Gross Salary
gross_salary = base_salary + bonus

# Step 2: Tax calculation
tax = (gross_salary * tax_rate) / 100

# Step 3: Net Salary
net_salary = gross_salary - tax - other_charges

# Output
print("Gross Salary =", gross_salary)
print("Tax =", tax)
print("Net Salary =", net_salary)

# %%
#Task: Bank Loan Approval System 
# Objective: You have to create a javascript script that checks whether an user is 
eligible for a bank loan based on various criteria. 
# Hints: 
# The applicant's age must be between 18 and 60 years. 
# The applicant's monthly income must be greater than or equal to ₹25000. 
○# The applicant's credit score must be greater than or equal to 700. 
○ #The applicant must not have any outstanding debts greater than ₹10000 
1. Output: 
○ Display "Loan Approved" if the applicant meets all the conditions. 
○ Otherwise display "Loan Rejected".

# %%
age = int(input("Enter your age: "))

if 18 <= age <= 60:

    income = int(input("Enter your income: "))
    credit_score = int(input("Enter your credit score: "))
    debt = int(input("Enter your outstanding debt: "))

    if income >= 25000 and credit_score >= 700 and debt <= 10000:
        print("Loan Approved")
    else:
        print("Loan Rejected")

else:
    print("Loan Rejected (Age not eligible)")
# Out:
# Enter your age:  15
# Loan Rejected (Age not eligible)

# %%
# 7 
score = float(input("Enter academic score: "))

if score >= 60:
    print("Academic score OK")

    attendance = float(input("Enter attendance percentage: "))

    if attendance >= 75:
        print("Attendance OK")

        activity = input("Extracurricular participation (yes/no): ")

        if activity == "yes":
            print("Eligible for Interview")
        else:
            print("Not Eligible for Interview (No extracurricular activity)")
    else:
        print("Not Eligible for Interview (Low attendance)")
else:
    print("Not Eligible for Interview (Low academic score)")
# Out:
# Enter academic score:  67
# Academic score OK
# Enter attendance percentage:  89
# Attendance OK
# Extracurricular participation (yes/no):  yes
# Eligible for Interview

# %%
#9
email=input("enter your email address")
if "@gmail.com" in email:
    print(f"Your {email} is eligible for registration")
else:
    print(f" Sorry {email} is not  eligible for registration")
# Out:
# enter your email address rish@gmail.com
# Your rish@gmail.com is eligible for registration

# %%
#10
marks=int(input("enter your marks="))
if marks>=90 and marks<=100:
    print("Grade A")
elif marks>=80 and marks<=89:
    print("Grade B ")
elif marks>=70 and marks<=79:
    print("Grade C")
elif marks>=60 and marks<=69:
    print("Grade D")
elif marks>=50 and marks<=59:
    print("Grade E")
elif marks>=0 and marks<=49:
    print("Grade F")
elif marks < 0 or marks > 100:
    print("Invalid marks")
else:
    print("Good Luck")
# Out:
# enter your marks= 789
# Invalid marks

# %%
#11
username=input("enter your username=")
password=input("enter your password=")

if username=="user1" and password=="pass@123":
    print("You are Succesfull Login")
else:
    print("Login error check email and password")
# Out:
# enter your username= rish
# enter your password= psjj
# Login error check email and password

# %%
#12 
experience = int(input("Enter years of experience: "))

if experience >= 10:
    salary = 80000
    print("Senior employee")

    if experience > 15:
        salary += 5000
        print("Experience exceeds 15 years. Bonus added.")

elif experience >= 5:
    salary = 50000
    print("Mid-level employee")

else:
    salary = 30000
    print("Junior employee")

print("Salary:", salary)
# Out:
# Enter years of experience:  18
# Senior employee
# Experience exceeds 15 years. Bonus added.
# Salary: 85000

# %%
#13 13. Library Charge Calculation 
#Problem Statement: 
#rite a javascript program that calculates the library charge based on the number of days a 
#book has been borrowed. 
#Charge Criteria: 
#● Up to 5 days: Rs. 2 per day 
#● 6 to 10 days: Rs. 3 per day 
#● 11 to 15 days: Rs. 4 per day 
#● More than 15 days: Rs. 5 per day 
#Instructions: 
#1. Input: Prompt the user to enter the number of days the book has been borrowed. 
#2. Processing: Calculate the charge based on the given criteria. 
#3. Output: Display the calculated charge. 


book_borrowed = int(input("Enter the number of days borrowed: "))

if book_borrowed <= 5:
    charge = book_borrowed * 2
elif book_borrowed <= 10:
    charge = book_borrowed * 3
elif book_borrowed <= 15:
    charge = book_borrowed * 4
else:
    charge = book_borrowed * 5

print("Library Charge =", charge)
# Out:
# Enter the number of days borrowed:  4
# Library Charge = 8

# %%
#14. Arranging Three Numbers in Descending Order 
#Task: 
#Write a javascript program to arrange three numbers in descending order. 
#Input: 
#Prompt the user to enter three numbers. 
#Processing: 
#Sort the numbers in descending order. 
#Example: 
#● Enter first number: 3 
#● Enter second number: 1 
#● Enter third number: 2 
#Output: 
#● Numbers in Descending Order: 3, 2, 1 

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))

numbers = [num1, num2, num3]
numbers.sort(reverse=True)

print("Numbers in Descending Order:", numbers)
# Out:
# Enter first number:  4
# Enter second number:  7
# Enter third number:  2
# Numbers in Descending Order: [7, 4, 2]

# %%
#15. Tax Calculation for Car Purchase 
#Write a  program to calculate the tax on a car purchase based on the car brand and its price. 
#1. Mahindra: 5% tax for prices between 7L (7 lakh) and 10L. 
#2. Audi: 10% tax for prices between 10L and 15L. 
#3. Jaguar: 25% tax for prices between 15L and 20L. 
#4. Mercedes: 30% tax for prices between 20L and 25L. 
#5. Input: The car brand and price. 
#6. Output: The calculated tax on the purchase. 

car_brand = input("Enter Car Brand: ")
price = int(input("Enter Car Price: "))

if car_brand == "Mahindra" and price >= 700000 and price <= 1000000:
    tax = price * 0.05

elif car_brand == "Audi" and price >= 1000000 and price <= 1500000:
    tax = price * 0.10

elif car_brand == "Jaguar" and price >= 1500000 and price <= 2000000:
    tax = price * 0.25

elif car_brand == "Mercedes" and price >= 2000000 and price <= 2500000:
    tax = price * 0.30

else:
    tax = 0
    print("No tax rule available for this car.")

print("Tax Amount =", tax)
# Out:
# Enter Car Brand:  bmw
# Enter Car Price:  400000
# No tax rule available for this car.
# Tax Amount = 0

# %%
#16.Finding the Middle Number 
#○ Task: Write a program to determine the middle number among three inputs. 
#○ Input: Prompt the user to enter three numbers. 
#○ Processing: Identify the middle number, which is neither the largest nor the 
#smallest. 
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))

if (num1 > num2 and num1 < num3) or (num1 < num2 and num1 > num3):
    print("Middle Number =", num1)

elif (num2 > num1 and num2 < num3) or (num2 < num1 and num2 > num3):
    print("Middle Number =", num2)

else:
    print("Middle Number =", num3)
# Out:
# Enter first number:  7
# Enter second number:  8
# Enter third number:  7
# Middle Number = 7

# %%
#17.Find the greatest number. 
# Task: Write a program to find greatest number from three number 
#Input: Prompt the user to enter three numbers. 
#  Output: Display the greatest number. 
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))

if num1 >= num2 and num1 >= num3:
    print("Greatest Number =", num1)

elif num2 >= num1 and num2 >= num3:
    print("Greatest Number =", num2)

else:
    print("Greatest Number =", num3)

# %%
#18.Authentication System
username=input("enter username=").lower()
password=input("enter the password=").lower()
if username=="user1":
    print(f"your {username} is correct")
    
    if password=="pass@123":
        print(f"You {password} is correct")
        
    else:
        print("You {password} is wrong")
        
else:
    print(f"Something Wrong Check Your Username and password ")
# Out:
# enter username= user1
# enter the password= pass@123
# your user1 is correct
# You pass@123 is correct

# %%
#19.Calculate Class Attendance Percentage 
# Task: Write a program to calculate the percentage of classes attended by a 
#student and determine their eligibility to sit in the exam. 
# Conditions: 
# Attendance percentage < 75%: Not eligible to sit in the exam. 
# Attendance percentage ≥ 75%: Eligible to sit in the exam. 
# Output: Display the attendance percentage and eligibility status. 

total_classes = int(input("Enter total number of classes: "))
attended_classes = int(input("Enter number of classes attended: "))

percentage = (attended_classes / total_classes) * 100

print("Attendance Percentage =", percentage, "%")

if percentage < 75:
    print("Status: Not Eligible to sit in exam")
else:
    print("Status: Eligible to sit in exam")
# Out:
# Enter total number of classes:  100
# Enter number of classes attended:  24
# Attendance Percentage = 24.0 %
# Status: Not Eligible to sit in exam

# %%
# 20 Task: Write a program to calculate the library charges based on the number of 
#days a book has been borrowed. 
## Up to 5 days: ₹2/day. 
#6 to 10 days: ₹3/day. 
# 11 to 15 days: ₹4/day. 
# More than 15 days: ₹5/day. 
# Output: Display the total charges.
days = int(input("Enter number of days: "))

if days <= 5:
    charge = days * 2
elif days <= 10:
    charge = days * 3
elif days <= 15:
    charge = days * 4
else:
    charge = days * 5

print("Total Charges = ₹", charge)
# Out:
# Enter number of days:  3
# Total Charges = ₹ 6

# %%
#21
age = int(input("Enter your age: "))

if age >= 21 and age <= 32:

    graduate = input("Are you a graduate (yes/no): ")

    if graduate == "yes":

        nationality = input("Enter nationality: ")

        if nationality.lower() == "indian":

            print("Eligible for UPSC")
            print("Proceed to Prelims")

            prelims = int(input("Enter Prelims Score: "))

            if prelims >= 700:

                print("Passed Prelims")
                print("Proceed to Mains")

                mains = int(input("Enter Mains Score: "))

                if mains >= 800:

                    print("Passed Mains")
                    print("Proceed to Interview")

                    interview = int(input("Enter Interview Score: "))

                    if interview >= 300:

                        print("Congratulations! You have cleared the UPSC.")
                    else:
                        print("You failed the Interview.")

                else:
                    print("You failed the Mains.")

            else:
                print("You failed the Prelims.")

        else:
            print("Ineligible: Nationality must be Indian.")

    else:
        print("Ineligible: Must be a graduate.")

else:
    print("Ineligible: Age must be between 21 and 32.")
# Out:
# enter your age= 22
# You are 22 is elligble for Upsc
# enter you are graduate or not= yes
# You are graudte
# enter your prelims marks= 600
# You failed the Prelims
# enter the mains marks= 750
# You failed the Mains
# enter the interview marks= 200
# Not Clear UPSC

# %%
#22
print("===== Login Menu =====")
print("1. Login with Phone")
print("2. Login with Email")
print("3. Exit")

choice = int(input("Enter your choice: "))

if choice == 1:
    phone = int(input("Enter Phone Number: "))
    otp = int(input("Enter OTP: "))

    if phone == 1234567890 and otp == 1234:
        print("Login successful with phone!")
    else:
        print("Invalid phone number or OTP.")

elif choice == 2:
    email = input("Enter Email: ")
    password = input("Enter Password: ")

    if email == "user@example.com" and password == "password123":
        print("Login successful with email!")
    else:
        print("Invalid email or password.")

elif choice == 3:
    print("Exiting the program. Have a nice day!")

else:
    print("Invalid choice. Please select a valid option.")
# Out:
# ===== Login Menu =====
# 1. Login with Phone
# 2. Login with Email
# 3. Exit
# Enter your choice:  2
# Enter Email:  rishav
# Enter Password:  2345
# Invalid email or password.
